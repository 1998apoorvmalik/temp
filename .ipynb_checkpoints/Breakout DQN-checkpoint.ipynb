# %%
from agent import DQNAgent
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import wrappers
import gym

env = wrappers.wrap_deepmind(gym.make("BreakoutDeterministic-v4"))
# Out:
# Using TensorFlow backend.

# %%
env.unwrapped.get_action_meanings()
# Out:
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT']

# %%
agent = DQNAgent(env)
# Out:
# WARNING:tensorflow:From C:\Users\apoor\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 20, 20, 32)        8224
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 32)          16416
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 32)          9248
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1568)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               401664
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 468,964
# Trainable params: 468,964
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 20, 20, 32)        8224
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 9, 9, 32)          16416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 32)          9248
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1568)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               401664
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_6 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 468,964
# Trainable params: 468,964
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 1st training session
# Training for 50k episodes
agent.run(num_episodes = 50000, mode = "train", weights_path = "./weights/model_weights_1", scores_path = "./logs/score_1")
# Out:
# Episode 32183/50000 | Episode Score: 3.0 | Min. Score: 0.0 | Max. Score: 14.0 | Current Avg. Score: 3.41 | Max. Average Score: 3.6 | epsilon: 0.2000495426038135298

# %%
# Training was interrupted 
# Elapsed time: 45 hrs
# Epsison: 0.2 | Max. Score: 14 | Max. Average Score: 3.6
# plotting the scores
data = pd.read_csv("./logs/score_1").values.flatten()
agent.plot_scores(data)

# %%
# Loading the model's weights trained so far
agent.model.load_weights("./weights/model_weights_1")
# Resetting the epsilon
agent.reset_exploration(epsilon=0.25)

# %%
# 2nd training session
agent.run(num_episodes = 30000, mode = "train", weights_path = "./weights/model_weights_2", scores_path = "./logs/score_2")
# Out:
# Episode 25423/30000 | Episode Score: 5.0 | Min. Score: 0.0 | Max. Score: 30.0 | Current Avg. Score: 5.39 | Max. Average Score: 6.89 | epsilon: 0.070124984166491285

# %%
# Training was interrupted 
# Elapsed time: 60hrs
# Epsison: 0.2 | Max. Score: 30 | Max. Average Score: 6.89
# plotting the scores
data = pd.read_csv("./logs/score_2").values.flatten()
agent.plot_scores(data)

# %%
# Loading the model's weights trained so far
agent.model.load_weights("./weights/model_weights_2")
# Resetting the epsilon
agent.reset_exploration(epsilon=0.06)

# %%
# 3rd training session
agent.run(num_episodes = 30000, mode = "train", weights_path = "./weights/model_weights_3", scores_path = "./logs/score_3")
# Out:
# Episode 6042/30000 | Episode Score: 2.0 | Min. Score: 0.0 | Max. Score: 34.0 | Current Avg. Score: 5.51 | Max. Average Score: 7.11 | epsilon: 0.0443555130793336726
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3b5a697613ea> in <module>
#       1 # 3rd training session
# ----> 2 agent.run(num_episodes = 30000, mode = "train", weights_path = "./weights/model_weights_3", scores_path = "./logs/score_3")
#
# ~\Desktop\Git Hub\New folder\agent.py in run(self, num_episodes, mode, time_delay, score_threshold, weights_path, scores_path)
#     176                 if mode=='test':
#     177                     env.render()
# --> 178                 next_state, reward, done, info = self.env.step(action)
#     179                 total_reward += reward
#     180                 action = self.act(next_state, reward, done, mode, time_delay)
#
# ~\Desktop\Git Hub\New folder\wrappers.py in step(self, action)
#     206
#     207     def step(self, action):
# --> 208         ob, reward, done, info = self.env.step(action)
#     209         self.frames.append(ob)
#     210         return self._get_ob(), reward, done, info
#
# ~\Anaconda3\lib\site-packages\gym\core.py in step(self, action)
#     271
#     272     def step(self, action):
# --> 273         observation, reward, done, info = self.env.step(action)
#     274         return observation, self.reward(reward), done, info
#     275
#
# ~\Anaconda3\lib\site-packages\gym\core.py in step(self, action)
#     260     def step(self, action):
#     261         observation, reward, done, info = self.env.step(action)
# --> 262         return self.observation(observation), reward, done, info
#     263
#     264     def observation(self, observation):
#
# ~\Desktop\Git Hub\New folder\wrappers.py in observation(self, obs)
#     172             frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
#     173         frame = cv2.resize(
# --> 174             frame, (self._width, self._height), interpolation=cv2.INTER_AREA
#     175         )
#     176         if self._grayscale:
#
# KeyboardInterrupt:
